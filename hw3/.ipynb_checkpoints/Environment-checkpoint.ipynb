# %%
__author__ = 'aqeel'
from math import pow
from random import randint
#Class to represent the state.
class State:
    def __init__(self,dealercard,playercard,Gamma):
        '''
        :param dealercard: Dealer black card
        :param playercard: player black card
        :param Gamma: discount value
        '''
        # Total of dealer cards sum
        self.dealersum=dealercard
        self.FirstDealerCard = dealercard
        # Total of Players cards
        self.playersum= playercard

        # Represent if someoe got busted
        self.terminated = False

        # No of Player draws
        self.Playerdraws=0

        # Player status
        self.PlayerBust=False

        # Dealer Status
        self.DealerBust=False

        # No of Dealer Draws
        self.Dealerdraws=0

        # discount value
        self.BaseGamma = Gamma
        
        # The Reward For The Current State
        self.Reward = 0

    def AddDrawnCardPlayer(self,value):
        '''
        add the drawn card value to player's sum and update the status of the game (ended or not ) & discount value
        :param value: signed integer from -10 to 10 represent the value and the color of the drawn card
        :return: Gamma for the current step
        '''
        if (self.terminated):
            print 'Game Ended Already'
        else:
            self.Playerdraws+=1

            if self.playersum+value>21:
                #'The player Busted.'
                self.terminated=True
                self.PlayerBust=True
            else:
                self.playersum+=value
                if self.playersum<1:
                    #'The player Busted.'
                    self.terminated=True
                    self.PlayerBust=True

    def AddDrawnCardDealer(self,value):
        '''
        add the drawn card value to dealer's sum and update the status of the game (ended or not ) & discount value
        :param value: signed integer from -10 to 10 represent the value and the color of the drawn card
        :return: Gamma for the current step
        '''
        if (self.terminated):
            print 'Game Ended Already'
        else:
            self.Dealerdraws+=1
            self.dealersum+=value
            if self.dealersum>21 or self.dealersum<1:
                #'The Dealer Busted'
                self.terminated=True
                self.DealerBust=True
            return pow(self.BaseGamma,self.Dealerdraws)

    def __str__(self):
        return 'Reward:{},Player Draws:{},Sum:{} ## Dealer Draws:{},Sum:{},First Card:{}'\
    .format(self.Reward,self.Playerdraws,self.playersum,self.Dealerdraws,self.dealersum,self.FirstDealerCard)

# %%
class Values:
    
    value=0
    occurence=0
    def UpdateValues(self,value):
        self.value +=value
        self.occurence += 1
values = {}
def AddValue(playersum , dealercard,value):
    if playersum<12:
        return
    if (playersum,dealercard) in values.keys():
        (values[(playersum,dealercard)]).UpdateValues(value)
    else:
        tmp = Values()
        tmp.UpdateValues(value)
        values[(playersum,dealercard)] = tmp

# %%
def DrawBlackCard():
    '''
    simulate draw a black card from (1-10) to use for the first draw
    :return:random integer from 1-10
    '''
    return randint(1,10)

def DrawCard():
    '''
    simulate draw a (red/black) from (1-10) card. with probability 1/3 for negative value and 2/3 for positive value
    :return:random integer from (-10 to 10)
    '''
    return ( DrawBlackCard() if randint(1,3)!=1 else  DrawBlackCard()*-1)
    #return value

def CheckReward(s):
    '''
    :param s: Game State(type State)
    :return:signed integer as reward(-1,0,1))
    '''
    reward=None
    #The Game Ended Already(Someone Got Busted)
    if s.terminated:
        #The Player busted
        if s.PlayerBust:
            s.Reward=-1
        #The Dealer busted
        elif s.DealerBust:
            s.Reward=1
         #No one Got Busted
        else:
            #Player score is higher than the dealer
            if s.playersum>s.dealersum:
                s.Reward=1
            #Dealer Score is higher than the player
            elif s.dealersum>s.playersum:
                s.Reward=-1
            #Dealer and Player scores equal
            else:
                s.Reward=0
    #Return reward
    return reward
    '''
    if reward==None:
        return reward
    else:
        return pow(s.BaseGamma,s.Playerdraws)*reward
    '''

def step(s,a):
    '''
    simulate the player single step, or dealer(all steps )
    :param s: the current state
    :param a: the action 0:hit ,1:stick
    :return: s' (the new  state ) and R ( the reward )
    '''
    if s.terminated:
        print 'Game Ended Already'
        return 0
    #Player is hitting
    if a==0:
        s.AddDrawnCardPlayer(DrawCard())
        return CheckReward(s)
    #The Player Stick , Dealer is hitting.
    elif a==1:
        #if game not terminated & the dealer sum is less than 17
        while not s.terminated and s.dealersum<17:
            s.AddDrawnCardDealer(DrawCard())
        #Either the dealer got busted or got more than 17
        s.terminated=True
        return CheckReward(s)

def GetPlayerAction():
    return (1 if Easy21.playersum>17 else 0)

for i in range (0,1000):
    #---Game Started -----#
    Easy21 = State(DrawBlackCard(),DrawBlackCard(),1)
    #---Inititation values ----#
    action = GetPlayerAction()
    while not Easy21.terminated:
        step(Easy21,action)
        
        if Easy21.terminated:
            print Easy21
            AddValue(Easy21.playersum,Easy21.FirstDealerCard,Easy21.Reward)
            break
        if action==1:
            break
        else:
            action=GetPlayerAction()
    #---Game Ended---#
# Out:
# Reward:1,Player Draws:1,Sum:19 ## Dealer Draws:1,Sum:0,First Card:5
# Reward:-1,Player Draws:4,Sum:15 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:2,Sum:19 ## Dealer Draws:2,Sum:20,First Card:10
# Reward:-1,Player Draws:1,Sum:-4 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:4,Sum:0 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:2,Sum:18 ## Dealer Draws:2,Sum:20,First Card:2
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:2,Sum:18 ## Dealer Draws:2,Sum:21,First Card:7
# Reward:1,Player Draws:2,Sum:21 ## Dealer Draws:4,Sum:19,First Card:6
# Reward:1,Player Draws:4,Sum:21 ## Dealer Draws:3,Sum:22,First Card:8
# Reward:-1,Player Draws:2,Sum:0 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:1,Player Draws:16,Sum:19 ## Dealer Draws:2,Sum:22,First Card:7
# Reward:-1,Player Draws:5,Sum:17 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:1,Sum:20 ## Dealer Draws:4,Sum:-1,First Card:2
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:3,Sum:0 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:6,Sum:15 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:1,Player Draws:2,Sum:21 ## Dealer Draws:2,Sum:-5,First Card:3
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:1,Sum:-5 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:1,Player Draws:10,Sum:20 ## Dealer Draws:5,Sum:17,First Card:9
# Reward:1,Player Draws:3,Sum:21 ## Dealer Draws:7,Sum:22,First Card:10
# Reward:-1,Player Draws:6,Sum:19 ## Dealer Draws:8,Sum:21,First Card:8
# Reward:-1,Player Draws:2,Sum:-3 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:2,Sum:15 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:5,Sum:13 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:6,Sum:13 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:1,Sum:-5 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:3,Sum:0 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:1,Sum:-2 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:2,Sum:-2 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:2,Sum:0 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:1,Player Draws:1,Sum:18 ## Dealer Draws:1,Sum:-5,First Card:2
# Reward:-1,Player Draws:7,Sum:14 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:3,Sum:18 ## Dealer Draws:2,Sum:20,First Card:9
# Reward:-1,Player Draws:3,Sum:-5 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:1,Player Draws:3,Sum:18 ## Dealer Draws:7,Sum:17,First Card:7
# Reward:1,Player Draws:1,Sum:20 ## Dealer Draws:1,Sum:17,First Card:10
# Reward:-1,Player Draws:2,Sum:-1 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:3,Sum:18 ## Dealer Draws:10,Sum:20,First Card:1
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:2,Sum:0 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:1,Sum:-5 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:3,Sum:-3 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:3,Sum:16 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:1,Player Draws:8,Sum:21 ## Dealer Draws:3,Sum:-3,First Card:1
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:1,Player Draws:4,Sum:20 ## Dealer Draws:1,Sum:-8,First Card:1
# Reward:-1,Player Draws:2,Sum:-4 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:1,Sum:-3 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:1,Player Draws:5,Sum:19 ## Dealer Draws:4,Sum:-5,First Card:7
# Reward:-1,Player Draws:4,Sum:17 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:1,Player Draws:1,Sum:19 ## Dealer Draws:2,Sum:-1,First Card:9
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:4,Sum:0 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:2,Sum:-2 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:2,Sum:0 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:4,Sum:18 ## Dealer Draws:3,Sum:20,First Card:6
# Reward:-1,Player Draws:4,Sum:16 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:0,Player Draws:4,Sum:18 ## Dealer Draws:3,Sum:18,First Card:9
# Reward:-1,Player Draws:1,Sum:-4 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:1,Player Draws:2,Sum:18 ## Dealer Draws:4,Sum:22,First Card:8
# Reward:-1,Player Draws:3,Sum:-1 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:3,Sum:14 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:6,Sum:-2 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:1,Player Draws:2,Sum:19 ## Dealer Draws:1,Sum:17,First Card:10
# Reward:1,Player Draws:5,Sum:19 ## Dealer Draws:4,Sum:24,First Card:5
# Reward:1,Player Draws:7,Sum:18 ## Dealer Draws:2,Sum:17,First Card:9
# Reward:-1,Player Draws:5,Sum:16 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:3,Sum:16 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:1,Player Draws:7,Sum:20 ## Dealer Draws:1,Sum:0,First Card:9
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:5,Sum:-2 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:1,Sum:-3 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:2,Sum:14 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:3,Sum:-1 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:1,Sum:-4 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:1,Player Draws:3,Sum:21 ## Dealer Draws:2,Sum:24,First Card:10
# Reward:-1,Player Draws:1,Sum:-7 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:5,Sum:-2 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:1,Player Draws:6,Sum:19 ## Dealer Draws:2,Sum:17,First Card:8
# Reward:1,Player Draws:4,Sum:18 ## Dealer Draws:12,Sum:-4,First Card:9
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:1,Sum:-4 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:2,Sum:14 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:1,Player Draws:3,Sum:20 ## Dealer Draws:1,Sum:0,First Card:4
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:1,Player Draws:6,Sum:19 ## Dealer Draws:2,Sum:18,First Card:7
# Reward:0,Player Draws:2,Sum:18 ## Dealer Draws:9,Sum:18,First Card:1
# Reward:1,Player Draws:4,Sum:18 ## Dealer Draws:3,Sum:-5,First Card:7
# Reward:-1,Player Draws:4,Sum:-3 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:3,Sum:17 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:2,Sum:-3 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:1,Player Draws:7,Sum:19 ## Dealer Draws:2,Sum:17,First Card:4
# Reward:-1,Player Draws:3,Sum:17 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:1,Player Draws:4,Sum:19 ## Dealer Draws:1,Sum:17,First Card:8
# Reward:1,Player Draws:9,Sum:20 ## Dealer Draws:4,Sum:22,First Card:8
# Reward:1,Player Draws:2,Sum:19 ## Dealer Draws:4,Sum:0,First Card:9
# Reward:1,Player Draws:2,Sum:21 ## Dealer Draws:4,Sum:22,First Card:9
# Reward:-1,Player Draws:2,Sum:-2 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:1,Player Draws:1,Sum:19 ## Dealer Draws:4,Sum:23,First Card:2
# Reward:-1,Player Draws:6,Sum:16 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:4,Sum:-4 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:3,Sum:13 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:8,Sum:-3 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:6,Sum:14 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:1,Player Draws:2,Sum:20 ## Dealer Draws:1,Sum:0,First Card:1
# Reward:1,Player Draws:2,Sum:19 ## Dealer Draws:4,Sum:24,First Card:3
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:1,Player Draws:3,Sum:21 ## Dealer Draws:1,Sum:0,First Card:6
# Reward:-1,Player Draws:2,Sum:16 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:1,Player Draws:4,Sum:18 ## Dealer Draws:1,Sum:-5,First Card:1
# Reward:-1,Player Draws:8,Sum:15 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:2,Sum:18 ## Dealer Draws:2,Sum:19,First Card:4
# Reward:1,Player Draws:5,Sum:20 ## Dealer Draws:4,Sum:-1,First Card:6
# Reward:-1,Player Draws:4,Sum:18 ## Dealer Draws:2,Sum:20,First Card:5
# Reward:1,Player Draws:8,Sum:21 ## Dealer Draws:3,Sum:-4,First Card:3
# Reward:1,Player Draws:2,Sum:18 ## Dealer Draws:2,Sum:0,First Card:6
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:1,Sum:-5 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:3,Sum:-1 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:3,Sum:-2 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:1,Player Draws:13,Sum:21 ## Dealer Draws:2,Sum:22,First Card:4
# Reward:-1,Player Draws:5,Sum:-1 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:2,Sum:-2 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:8,Sum:15 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:6,Sum:18 ## Dealer Draws:2,Sum:19,First Card:6
# Reward:-1,Player Draws:2,Sum:0 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:1,Player Draws:3,Sum:19 ## Dealer Draws:1,Sum:-5,First Card:1
# Reward:1,Player Draws:2,Sum:21 ## Dealer Draws:1,Sum:-2,First Card:8
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:1,Sum:-2 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:2,Sum:-7 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:2,Sum:15 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:1,Player Draws:4,Sum:18 ## Dealer Draws:1,Sum:0,First Card:9
# Reward:-1,Player Draws:3,Sum:17 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:3,Sum:0 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:1,Player Draws:5,Sum:20 ## Dealer Draws:2,Sum:22,First Card:5
# Reward:-1,Player Draws:7,Sum:17 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:1,Player Draws:4,Sum:19 ## Dealer Draws:1,Sum:18,First Card:10
# Reward:-1,Player Draws:4,Sum:15 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:0,Player Draws:2,Sum:18 ## Dealer Draws:3,Sum:18,First Card:5
# Reward:1,Player Draws:4,Sum:21 ## Dealer Draws:2,Sum:18,First Card:8
# Reward:-1,Player Draws:4,Sum:18 ## Dealer Draws:3,Sum:20,First Card:7
# Reward:-1,Player Draws:3,Sum:16 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:6,Sum:-1 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:0,Player Draws:1,Sum:18 ## Dealer Draws:4,Sum:18,First Card:5
# Reward:-1,Player Draws:2,Sum:-4 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:6,Sum:16 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:1,Player Draws:2,Sum:21 ## Dealer Draws:5,Sum:17,First Card:10
# Reward:1,Player Draws:3,Sum:21 ## Dealer Draws:5,Sum:0,First Card:8
# Reward:1,Player Draws:3,Sum:19 ## Dealer Draws:2,Sum:-2,First Card:4
# Reward:0,Player Draws:5,Sum:20 ## Dealer Draws:2,Sum:20,First Card:6
# Reward:-1,Player Draws:1,Sum:-5 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:1,Sum:-2 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:1,Player Draws:6,Sum:18 ## Dealer Draws:3,Sum:17,First Card:7
# Reward:-1,Player Draws:14,Sum:15 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:2,Sum:16 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:7,Sum:16 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:0,Player Draws:1,Sum:18 ## Dealer Draws:4,Sum:18,First Card:1
# Reward:1,Player Draws:2,Sum:18 ## Dealer Draws:3,Sum:24,First Card:9
# Reward:-1,Player Draws:8,Sum:-4 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:5,Sum:17 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:1,Player Draws:2,Sum:19 ## Dealer Draws:6,Sum:17,First Card:3
# Reward:-1,Player Draws:1,Sum:-5 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:1,Sum:18 ## Dealer Draws:4,Sum:21,First Card:3
# Reward:-1,Player Draws:7,Sum:16 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:3,Sum:19 ## Dealer Draws:1,Sum:20,First Card:10
# Reward:-1,Player Draws:2,Sum:-3 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:2,Sum:16 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:10,Sum:19 ## Dealer Draws:2,Sum:21,First Card:8
# Reward:-1,Player Draws:1,Sum:-5 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:1,Sum:-4 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:2,Sum:15 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:5,Sum:13 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:0,Player Draws:2,Sum:18 ## Dealer Draws:2,Sum:18,First Card:4
# Reward:-1,Player Draws:4,Sum:18 ## Dealer Draws:5,Sum:21,First Card:8
# Reward:-1,Player Draws:4,Sum:-3 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:3,Sum:21 ## Dealer Draws:1,Sum:0,First Card:4
# Reward:1,Player Draws:7,Sum:19 ## Dealer Draws:1,Sum:18,First Card:8
# Reward:-1,Player Draws:5,Sum:19 ## Dealer Draws:2,Sum:20,First Card:9
# Reward:1,Player Draws:3,Sum:19 ## Dealer Draws:7,Sum:24,First Card:10
# Reward:1,Player Draws:4,Sum:20 ## Dealer Draws:3,Sum:17,First Card:10
# Reward:1,Player Draws:2,Sum:20 ## Dealer Draws:7,Sum:22,First Card:2
# Reward:-1,Player Draws:1,Sum:-4 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:1,Player Draws:3,Sum:20 ## Dealer Draws:5,Sum:0,First Card:5
# Reward:1,Player Draws:12,Sum:21 ## Dealer Draws:4,Sum:25,First Card:2
# Reward:1,Player Draws:9,Sum:21 ## Dealer Draws:2,Sum:-3,First Card:2
# Reward:-1,Player Draws:1,Sum:-7 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:2,Sum:19 ## Dealer Draws:1,Sum:-4,First Card:3
# Reward:-1,Player Draws:2,Sum:-8 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:1,Player Draws:1,Sum:18 ## Dealer Draws:2,Sum:17,First Card:7
# Reward:-1,Player Draws:6,Sum:13 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:1,Player Draws:4,Sum:20 ## Dealer Draws:4,Sum:23,First Card:4
# Reward:-1,Player Draws:3,Sum:13 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:1,Sum:19 ## Dealer Draws:2,Sum:17,First Card:8
# Reward:1,Player Draws:2,Sum:21 ## Dealer Draws:1,Sum:-1,First Card:4
# Reward:-1,Player Draws:2,Sum:17 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:6,Sum:13 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:1,Player Draws:3,Sum:20 ## Dealer Draws:5,Sum:24,First Card:5
# Reward:-1,Player Draws:1,Sum:-8 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:1,Sum:-3 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:4,Sum:17 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:2,Sum:-2 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:2,Sum:0 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:5,Sum:-4 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:1,Player Draws:5,Sum:18 ## Dealer Draws:5,Sum:17,First Card:5
# Reward:-1,Player Draws:1,Sum:-3 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:1,Player Draws:4,Sum:19 ## Dealer Draws:1,Sum:18,First Card:10
# Reward:1,Player Draws:3,Sum:19 ## Dealer Draws:1,Sum:-1,First Card:3
# Reward:-1,Player Draws:2,Sum:-1 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:1,Player Draws:3,Sum:18 ## Dealer Draws:1,Sum:-4,First Card:4
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:2,Sum:-2 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:1,Player Draws:4,Sum:18 ## Dealer Draws:2,Sum:-2,First Card:5
# Reward:-1,Player Draws:2,Sum:-7 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:2,Sum:15 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:1,Player Draws:4,Sum:18 ## Dealer Draws:3,Sum:17,First Card:9
# Reward:-1,Player Draws:2,Sum:-4 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:3,Sum:18 ## Dealer Draws:2,Sum:17,First Card:7
# Reward:-1,Player Draws:4,Sum:13 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:9,Sum:15 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:1,Player Draws:3,Sum:19 ## Dealer Draws:1,Sum:0,First Card:3
# Reward:-1,Player Draws:3,Sum:0 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:2,Sum:-9 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:15,Sum:16 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:0,Player Draws:3,Sum:19 ## Dealer Draws:3,Sum:19,First Card:3
# Reward:-1,Player Draws:6,Sum:17 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:2,Sum:0 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:3,Sum:-3 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:1,Player Draws:18,Sum:19 ## Dealer Draws:8,Sum:24,First Card:2
# Reward:-1,Player Draws:5,Sum:-3 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:2,Sum:18 ## Dealer Draws:2,Sum:19,First Card:6
# Reward:1,Player Draws:1,Sum:19 ## Dealer Draws:2,Sum:18,First Card:8
# Reward:-1,Player Draws:5,Sum:14 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:1,Sum:-5 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:1,Sum:-5 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:1,Player Draws:4,Sum:21 ## Dealer Draws:1,Sum:-8,First Card:1
# Reward:-1,Player Draws:2,Sum:0 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:2,Sum:15 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:2,Sum:17 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:1,Player Draws:2,Sum:20 ## Dealer Draws:2,Sum:0,First Card:6
# Reward:-1,Player Draws:5,Sum:-1 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:1,Player Draws:1,Sum:18 ## Dealer Draws:3,Sum:22,First Card:5
# Reward:-1,Player Draws:4,Sum:16 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:1,Sum:-2 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:1,Player Draws:2,Sum:20 ## Dealer Draws:1,Sum:-7,First Card:3
# Reward:-1,Player Draws:10,Sum:0 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:4,Sum:-2 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:1,Sum:-5 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:1,Player Draws:3,Sum:19 ## Dealer Draws:3,Sum:0,First Card:6
# Reward:1,Player Draws:3,Sum:21 ## Dealer Draws:1,Sum:-2,First Card:7
# Reward:1,Player Draws:5,Sum:19 ## Dealer Draws:1,Sum:0,First Card:1
# Reward:1,Player Draws:7,Sum:21 ## Dealer Draws:1,Sum:-2,First Card:5
# Reward:-1,Player Draws:1,Sum:-3 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:2,Sum:16 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:6,Sum:14 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:1,Sum:-2 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:2,Sum:13 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:9,Sum:17 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:2,Sum:13 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:3,Sum:19 ## Dealer Draws:6,Sum:20,First Card:9
# Reward:1,Player Draws:2,Sum:18 ## Dealer Draws:2,Sum:23,First Card:6
# Reward:-1,Player Draws:1,Sum:-2 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:6,Sum:0 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:1,Player Draws:3,Sum:21 ## Dealer Draws:4,Sum:-3,First Card:10
# Reward:-1,Player Draws:2,Sum:0 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:2,Sum:-1 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:1,Player Draws:2,Sum:20 ## Dealer Draws:2,Sum:-4,First Card:2
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:1,Sum:-9 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:4,Sum:-1 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:10,Sum:-5 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:1,Sum:-5 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:8,Sum:-3 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:1,Sum:-7 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:7,Sum:-1 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:1,Player Draws:4,Sum:21 ## Dealer Draws:1,Sum:0,First Card:8
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:0,Player Draws:1,Sum:19 ## Dealer Draws:2,Sum:19,First Card:3
# Reward:-1,Player Draws:2,Sum:0 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:15,Sum:0 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:1,Sum:-6 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:6,Sum:17 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:4,Sum:19 ## Dealer Draws:4,Sum:20,First Card:9
# Reward:-1,Player Draws:2,Sum:-4 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:1,Player Draws:1,Sum:18 ## Dealer Draws:2,Sum:-3,First Card:2
# Reward:0,Player Draws:2,Sum:18 ## Dealer Draws:16,Sum:18,First Card:1
# Reward:1,Player Draws:6,Sum:20 ## Dealer Draws:1,Sum:-5,First Card:2
# Reward:-1,Player Draws:1,Sum:-4 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:2,Sum:14 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:6,Sum:16 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:1,Player Draws:2,Sum:20 ## Dealer Draws:2,Sum:24,First Card:6
# Reward:-1,Player Draws:2,Sum:-7 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:1,Player Draws:9,Sum:20 ## Dealer Draws:1,Sum:-4,First Card:3
# Reward:-1,Player Draws:1,Sum:-4 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:6,Sum:12 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:1,Player Draws:3,Sum:18 ## Dealer Draws:1,Sum:-8,First Card:2
# Reward:1,Player Draws:3,Sum:19 ## Dealer Draws:4,Sum:24,First Card:3
# Reward:-1,Player Draws:1,Sum:-4 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:5,Sum:-1 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:4,Sum:17 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:5,Sum:-4 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:1,Player Draws:3,Sum:21 ## Dealer Draws:1,Sum:-2,First Card:2
# Reward:-1,Player Draws:2,Sum:14 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:2,Sum:15 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:1,Sum:-6 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:6,Sum:15 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:1,Player Draws:3,Sum:21 ## Dealer Draws:4,Sum:-2,First Card:1
# Reward:-1,Player Draws:1,Sum:-7 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:4,Sum:0 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:2,Sum:-2 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:1,Player Draws:2,Sum:21 ## Dealer Draws:1,Sum:-6,First Card:2
# Reward:-1,Player Draws:7,Sum:0 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:6,Sum:21 ## Dealer Draws:1,Sum:20,First Card:10
# Reward:-1,Player Draws:5,Sum:-1 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:1,Player Draws:2,Sum:18 ## Dealer Draws:3,Sum:-1,First Card:2
# Reward:-1,Player Draws:1,Sum:-5 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:1,Sum:-4 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:1,Player Draws:2,Sum:19 ## Dealer Draws:5,Sum:18,First Card:1
# Reward:-1,Player Draws:2,Sum:-3 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:5,Sum:14 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:1,Player Draws:3,Sum:20 ## Dealer Draws:6,Sum:24,First Card:3
# Reward:-1,Player Draws:2,Sum:-1 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:1,Sum:-4 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:0,Player Draws:2,Sum:18 ## Dealer Draws:5,Sum:18,First Card:9
# Reward:-1,Player Draws:1,Sum:-8 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:3,Sum:15 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:4,Sum:-1 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:6,Sum:-2 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:3,Sum:0 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:2,Sum:0 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:9,Sum:19 ## Dealer Draws:2,Sum:20,First Card:7
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:1,Player Draws:4,Sum:21 ## Dealer Draws:2,Sum:20,First Card:6
# Reward:-1,Player Draws:1,Sum:-3 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:3,Sum:-7 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:1,Player Draws:4,Sum:20 ## Dealer Draws:1,Sum:-5,First Card:4
# Reward:-1,Player Draws:2,Sum:0 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:1,Sum:-4 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:2,Sum:15 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:3,Sum:18 ## Dealer Draws:14,Sum:20,First Card:1
# Reward:-1,Player Draws:9,Sum:13 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:4,Sum:15 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:1,Sum:-2 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:1,Sum:-3 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:3,Sum:17 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:5,Sum:15 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:4,Sum:18 ## Dealer Draws:2,Sum:17,First Card:5
# Reward:-1,Player Draws:3,Sum:0 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:1,Sum:18 ## Dealer Draws:2,Sum:21,First Card:9
# Reward:-1,Player Draws:3,Sum:0 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:3,Sum:13 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:1,Sum:-4 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:6,Sum:13 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:8,Sum:15 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:0,Player Draws:2,Sum:18 ## Dealer Draws:2,Sum:18,First Card:7
# Reward:1,Player Draws:2,Sum:20 ## Dealer Draws:4,Sum:23,First Card:7
# Reward:1,Player Draws:1,Sum:18 ## Dealer Draws:5,Sum:-2,First Card:2
# Reward:-1,Player Draws:2,Sum:-3 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:2,Sum:20 ## Dealer Draws:1,Sum:19,First Card:10
# Reward:-1,Player Draws:4,Sum:14 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:5,Sum:15 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:1,Player Draws:2,Sum:19 ## Dealer Draws:5,Sum:22,First Card:6
# Reward:-1,Player Draws:4,Sum:17 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:1,Sum:-5 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:3,Sum:21 ## Dealer Draws:2,Sum:19,First Card:6
# Reward:-1,Player Draws:3,Sum:-2 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:1,Player Draws:3,Sum:19 ## Dealer Draws:5,Sum:23,First Card:8
# Reward:-1,Player Draws:10,Sum:14 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:2,Sum:-5 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:5,Sum:14 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:1,Player Draws:3,Sum:18 ## Dealer Draws:1,Sum:0,First Card:1
# Reward:-1,Player Draws:3,Sum:20 ## Dealer Draws:2,Sum:21,First Card:8
# Reward:-1,Player Draws:1,Sum:18 ## Dealer Draws:4,Sum:21,First Card:9
# Reward:0,Player Draws:4,Sum:18 ## Dealer Draws:2,Sum:18,First Card:8
# Reward:1,Player Draws:3,Sum:18 ## Dealer Draws:1,Sum:17,First Card:9
# Reward:-1,Player Draws:1,Sum:-8 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:1,Player Draws:5,Sum:18 ## Dealer Draws:2,Sum:17,First Card:6
# Reward:-1,Player Draws:4,Sum:16 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:4,Sum:-2 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:1,Player Draws:4,Sum:20 ## Dealer Draws:2,Sum:-9,First Card:8
# Reward:1,Player Draws:5,Sum:21 ## Dealer Draws:6,Sum:17,First Card:4
# Reward:-1,Player Draws:4,Sum:0 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:1,Sum:-7 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:2,Sum:-6 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:3,Sum:16 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:1,Sum:-6 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:5,Sum:15 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:9,Sum:15 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:2,Sum:15 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:1,Player Draws:7,Sum:21 ## Dealer Draws:2,Sum:18,First Card:8
# Reward:-1,Player Draws:3,Sum:-3 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:1,Player Draws:8,Sum:18 ## Dealer Draws:5,Sum:-2,First Card:7
# Reward:1,Player Draws:1,Sum:19 ## Dealer Draws:7,Sum:-3,First Card:4
# Reward:1,Player Draws:4,Sum:21 ## Dealer Draws:1,Sum:-8,First Card:1
# Reward:-1,Player Draws:1,Sum:-3 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:4,Sum:-4 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:2,Sum:-6 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:6,Sum:19 ## Dealer Draws:2,Sum:21,First Card:1
# Reward:-1,Player Draws:8,Sum:-4 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:1,Player Draws:2,Sum:18 ## Dealer Draws:1,Sum:-7,First Card:2
# Reward:1,Player Draws:3,Sum:20 ## Dealer Draws:1,Sum:0,First Card:10
# Reward:-1,Player Draws:8,Sum:-3 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:7,Sum:14 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:1,Sum:-3 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:2,Sum:14 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:8,Sum:-4 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:3,Sum:17 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:3,Sum:-5 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:7,Sum:-3 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:1,Player Draws:2,Sum:18 ## Dealer Draws:6,Sum:-5,First Card:1
# Reward:-1,Player Draws:1,Sum:-2 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:6,Sum:15 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:1,Player Draws:3,Sum:18 ## Dealer Draws:1,Sum:0,First Card:6
# Reward:-1,Player Draws:4,Sum:17 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:1,Player Draws:4,Sum:19 ## Dealer Draws:1,Sum:-4,First Card:5
# Reward:-1,Player Draws:2,Sum:-2 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:2,Sum:-2 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:2,Sum:0 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:4,Sum:-1 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:5,Sum:14 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:1,Player Draws:10,Sum:19 ## Dealer Draws:1,Sum:-3,First Card:4
# Reward:-1,Player Draws:4,Sum:0 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:1,Player Draws:3,Sum:21 ## Dealer Draws:1,Sum:20,First Card:10
# Reward:-1,Player Draws:3,Sum:-2 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:8,Sum:16 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:4,Sum:18 ## Dealer Draws:7,Sum:19,First Card:2
# Reward:1,Player Draws:2,Sum:18 ## Dealer Draws:6,Sum:23,First Card:4
# Reward:-1,Player Draws:1,Sum:-6 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:4,Sum:13 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:1,Player Draws:1,Sum:18 ## Dealer Draws:5,Sum:0,First Card:5
# Reward:-1,Player Draws:1,Sum:-5 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:2,Sum:18 ## Dealer Draws:4,Sum:20,First Card:9
# Reward:1,Player Draws:6,Sum:19 ## Dealer Draws:4,Sum:25,First Card:8
# Reward:-1,Player Draws:6,Sum:18 ## Dealer Draws:2,Sum:21,First Card:9
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:5,Sum:-4 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:1,Player Draws:2,Sum:18 ## Dealer Draws:13,Sum:0,First Card:2
# Reward:1,Player Draws:4,Sum:18 ## Dealer Draws:1,Sum:17,First Card:8
# Reward:-1,Player Draws:3,Sum:15 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:1,Sum:-7 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:1,Player Draws:1,Sum:18 ## Dealer Draws:2,Sum:17,First Card:6
# Reward:-1,Player Draws:4,Sum:16 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:2,Sum:0 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:1,Player Draws:2,Sum:20 ## Dealer Draws:2,Sum:18,First Card:5
# Reward:-1,Player Draws:3,Sum:-6 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:5,Sum:14 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:1,Sum:-2 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:3,Sum:15 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:3,Sum:16 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:1,Sum:-4 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:2,Sum:-2 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:1,Player Draws:2,Sum:20 ## Dealer Draws:2,Sum:18,First Card:4
# Reward:1,Player Draws:5,Sum:21 ## Dealer Draws:1,Sum:-8,First Card:1
# Reward:-1,Player Draws:2,Sum:17 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:1,Player Draws:3,Sum:19 ## Dealer Draws:2,Sum:-1,First Card:4
# Reward:-1,Player Draws:2,Sum:12 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:1,Player Draws:7,Sum:20 ## Dealer Draws:1,Sum:-3,First Card:5
# Reward:-1,Player Draws:2,Sum:14 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:1,Player Draws:2,Sum:21 ## Dealer Draws:3,Sum:20,First Card:8
# Reward:-1,Player Draws:1,Sum:-6 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:1,Player Draws:4,Sum:20 ## Dealer Draws:5,Sum:-4,First Card:2
# Reward:-1,Player Draws:2,Sum:17 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:1,Player Draws:1,Sum:18 ## Dealer Draws:2,Sum:-8,First Card:6
# Reward:1,Player Draws:4,Sum:21 ## Dealer Draws:4,Sum:25,First Card:8
# Reward:1,Player Draws:6,Sum:19 ## Dealer Draws:3,Sum:17,First Card:9
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:3,Sum:17 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:6,Sum:0 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:3,Sum:15 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:2,Sum:16 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:5,Sum:15 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:1,Player Draws:2,Sum:20 ## Dealer Draws:3,Sum:18,First Card:4
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:1,Sum:-7 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:1,Sum:-4 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:1,Player Draws:1,Sum:19 ## Dealer Draws:1,Sum:-3,First Card:6
# Reward:0,Player Draws:2,Sum:19 ## Dealer Draws:12,Sum:19,First Card:10
# Reward:-1,Player Draws:2,Sum:-7 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:2,Sum:-4 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:1,Player Draws:4,Sum:18 ## Dealer Draws:3,Sum:-3,First Card:2
# Reward:-1,Player Draws:4,Sum:13 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:1,Player Draws:4,Sum:20 ## Dealer Draws:2,Sum:17,First Card:6
# Reward:-1,Player Draws:3,Sum:-5 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:7,Sum:15 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:6,Sum:-1 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:5,Sum:12 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:4,Sum:-3 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:2,Sum:20 ## Dealer Draws:5,Sum:21,First Card:3
# Reward:-1,Player Draws:1,Sum:-2 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:2,Sum:17 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:2,Sum:-2 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:1,Sum:-2 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:1,Sum:-7 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:1,Player Draws:1,Sum:18 ## Dealer Draws:2,Sum:-5,First Card:2
# Reward:-1,Player Draws:1,Sum:-3 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:1,Sum:-4 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:2,Sum:-3 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:6,Sum:13 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:4,Sum:-3 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:9,Sum:0 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:1,Player Draws:3,Sum:19 ## Dealer Draws:3,Sum:-1,First Card:1
# Reward:1,Player Draws:2,Sum:21 ## Dealer Draws:3,Sum:23,First Card:4
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:1,Player Draws:2,Sum:21 ## Dealer Draws:4,Sum:17,First Card:8
# Reward:-1,Player Draws:3,Sum:15 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:5,Sum:0 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:2,Sum:14 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:1,Sum:-3 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:2,Sum:13 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:2,Sum:0 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:1,Player Draws:10,Sum:18 ## Dealer Draws:2,Sum:17,First Card:3
# Reward:-1,Player Draws:2,Sum:13 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:7,Sum:21 ## Dealer Draws:5,Sum:19,First Card:7
# Reward:-1,Player Draws:2,Sum:15 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:17,Sum:17 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:6,Sum:16 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:1,Player Draws:1,Sum:19 ## Dealer Draws:4,Sum:24,First Card:9
# Reward:1,Player Draws:2,Sum:19 ## Dealer Draws:2,Sum:24,First Card:7
# Reward:-1,Player Draws:2,Sum:16 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:1,Player Draws:5,Sum:21 ## Dealer Draws:2,Sum:19,First Card:9
# Reward:1,Player Draws:2,Sum:19 ## Dealer Draws:2,Sum:18,First Card:5
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:6,Sum:-3 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:1,Player Draws:2,Sum:21 ## Dealer Draws:5,Sum:19,First Card:6
# Reward:1,Player Draws:2,Sum:19 ## Dealer Draws:2,Sum:0,First Card:3
# Reward:0,Player Draws:3,Sum:18 ## Dealer Draws:3,Sum:18,First Card:6
# Reward:-1,Player Draws:2,Sum:-8 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:2,Sum:15 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:2,Sum:12 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:8,Sum:-7 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:2,Sum:21 ## Dealer Draws:3,Sum:19,First Card:9
# Reward:-1,Player Draws:1,Sum:-3 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:1,Player Draws:3,Sum:20 ## Dealer Draws:1,Sum:-1,First Card:2
# Reward:-1,Player Draws:2,Sum:16 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:1,Player Draws:4,Sum:19 ## Dealer Draws:1,Sum:-4,First Card:3
# Reward:-1,Player Draws:4,Sum:0 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:5,Sum:18 ## Dealer Draws:2,Sum:17,First Card:10
# Reward:-1,Player Draws:1,Sum:-2 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:1,Player Draws:3,Sum:21 ## Dealer Draws:2,Sum:19,First Card:4
# Reward:-1,Player Draws:3,Sum:16 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:3,Sum:19 ## Dealer Draws:2,Sum:-1,First Card:10
# Reward:-1,Player Draws:5,Sum:12 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:1,Player Draws:3,Sum:20 ## Dealer Draws:4,Sum:24,First Card:3
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:2,Sum:-5 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:11,Sum:-1 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:4,Sum:-1 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:1,Player Draws:4,Sum:18 ## Dealer Draws:3,Sum:-1,First Card:2
# Reward:1,Player Draws:3,Sum:18 ## Dealer Draws:6,Sum:26,First Card:5
# Reward:-1,Player Draws:3,Sum:-1 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:2,Sum:-1 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:0,Player Draws:3,Sum:19 ## Dealer Draws:2,Sum:19,First Card:5
# Reward:-1,Player Draws:3,Sum:16 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:4,Sum:16 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:1,Sum:-3 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:1,Sum:-3 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:10,Sum:15 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:2,Sum:-4 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:1,Player Draws:5,Sum:19 ## Dealer Draws:5,Sum:25,First Card:7
# Reward:-1,Player Draws:5,Sum:15 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:3,Sum:-1 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:6,Sum:16 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:2,Sum:21 ## Dealer Draws:4,Sum:20,First Card:7
# Reward:1,Player Draws:6,Sum:20 ## Dealer Draws:7,Sum:24,First Card:1
# Reward:1,Player Draws:3,Sum:21 ## Dealer Draws:1,Sum:17,First Card:10
# Reward:-1,Player Draws:2,Sum:16 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:2,Sum:18 ## Dealer Draws:6,Sum:17,First Card:4
# Reward:-1,Player Draws:3,Sum:-5 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:2,Sum:16 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:6,Sum:19 ## Dealer Draws:4,Sum:18,First Card:2
# Reward:0,Player Draws:3,Sum:19 ## Dealer Draws:12,Sum:19,First Card:3
# Reward:-1,Player Draws:2,Sum:-4 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:1,Sum:-4 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:1,Sum:-7 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:1,Player Draws:2,Sum:19 ## Dealer Draws:1,Sum:17,First Card:9
# Reward:-1,Player Draws:2,Sum:19 ## Dealer Draws:5,Sum:21,First Card:2
# Reward:-1,Player Draws:6,Sum:18 ## Dealer Draws:5,Sum:19,First Card:8
# Reward:1,Player Draws:3,Sum:19 ## Dealer Draws:3,Sum:-2,First Card:7
# Reward:1,Player Draws:3,Sum:21 ## Dealer Draws:1,Sum:-6,First Card:2
# Reward:-1,Player Draws:8,Sum:-6 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:5,Sum:17 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:4,Sum:14 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:3,Sum:-4 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:2,Sum:14 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:5,Sum:21 ## Dealer Draws:5,Sum:24,First Card:7
# Reward:-1,Player Draws:4,Sum:18 ## Dealer Draws:3,Sum:21,First Card:4
# Reward:-1,Player Draws:3,Sum:-2 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:1,Sum:-5 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:15,Sum:17 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:3,Sum:14 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:1,Player Draws:3,Sum:21 ## Dealer Draws:2,Sum:19,First Card:5
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:3,Sum:15 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:6,Sum:14 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:1,Player Draws:1,Sum:19 ## Dealer Draws:5,Sum:23,First Card:5
# Reward:-1,Player Draws:5,Sum:15 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:1,Player Draws:3,Sum:18 ## Dealer Draws:1,Sum:-2,First Card:6
# Reward:-1,Player Draws:1,Sum:-4 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:3,Sum:-1 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:1,Player Draws:2,Sum:18 ## Dealer Draws:3,Sum:0,First Card:1
# Reward:-1,Player Draws:1,Sum:-6 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:2,Sum:-1 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:2,Sum:17 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:1,Player Draws:2,Sum:21 ## Dealer Draws:5,Sum:-1,First Card:7
# Reward:-1,Player Draws:5,Sum:-1 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:1,Sum:-5 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:4,Sum:-2 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:1,Player Draws:3,Sum:20 ## Dealer Draws:3,Sum:22,First Card:6
# Reward:-1,Player Draws:1,Sum:-6 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:1,Player Draws:3,Sum:20 ## Dealer Draws:4,Sum:23,First Card:9
# Reward:-1,Player Draws:2,Sum:16 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:1,Sum:-3 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:1,Player Draws:4,Sum:19 ## Dealer Draws:3,Sum:-1,First Card:5
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:1,Player Draws:2,Sum:20 ## Dealer Draws:4,Sum:-2,First Card:5
# Reward:-1,Player Draws:9,Sum:-2 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:5,Sum:13 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:7,Sum:0 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:1,Player Draws:4,Sum:20 ## Dealer Draws:4,Sum:-2,First Card:6
# Reward:-1,Player Draws:2,Sum:-6 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:1,Sum:-5 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:1,Player Draws:2,Sum:19 ## Dealer Draws:5,Sum:18,First Card:4
# Reward:0,Player Draws:5,Sum:18 ## Dealer Draws:2,Sum:18,First Card:10
# Reward:-1,Player Draws:6,Sum:16 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:3,Sum:-1 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:1,Player Draws:2,Sum:20 ## Dealer Draws:1,Sum:-1,First Card:4
# Reward:-1,Player Draws:4,Sum:16 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:6,Sum:16 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:1,Player Draws:7,Sum:19 ## Dealer Draws:1,Sum:18,First Card:8
# Reward:-1,Player Draws:4,Sum:-3 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:1,Sum:-2 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:3,Sum:14 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:2,Sum:0 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:1,Player Draws:3,Sum:20 ## Dealer Draws:2,Sum:17,First Card:7
# Reward:1,Player Draws:7,Sum:18 ## Dealer Draws:3,Sum:-5,First Card:1
# Reward:-1,Player Draws:10,Sum:-9 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:3,Sum:14 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:1,Sum:-6 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:1,Sum:-5 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:1,Player Draws:7,Sum:20 ## Dealer Draws:4,Sum:19,First Card:4
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:1,Player Draws:4,Sum:18 ## Dealer Draws:2,Sum:-2,First Card:5
# Reward:-1,Player Draws:3,Sum:12 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:1,Player Draws:3,Sum:18 ## Dealer Draws:2,Sum:22,First Card:7
# Reward:-1,Player Draws:2,Sum:18 ## Dealer Draws:2,Sum:19,First Card:8
# Reward:-1,Player Draws:6,Sum:-1 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:6,Sum:19 ## Dealer Draws:4,Sum:20,First Card:4
# Reward:-1,Player Draws:6,Sum:17 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:4,Sum:-3 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:2,Sum:16 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:3,Sum:-5 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:2,Sum:-2 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:2,Sum:14 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:3,Sum:0 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:1,Sum:20 ## Dealer Draws:7,Sum:19,First Card:7
# Reward:-1,Player Draws:4,Sum:16 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:1,Player Draws:1,Sum:19 ## Dealer Draws:9,Sum:-2,First Card:9
# Reward:-1,Player Draws:1,Sum:-9 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:1,Sum:-3 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:6,Sum:0 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:2,Sum:17 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:1,Player Draws:15,Sum:18 ## Dealer Draws:2,Sum:17,First Card:5
# Reward:-1,Player Draws:4,Sum:-5 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:1,Player Draws:6,Sum:20 ## Dealer Draws:1,Sum:-9,First Card:1
# Reward:1,Player Draws:3,Sum:20 ## Dealer Draws:1,Sum:0,First Card:6
# Reward:-1,Player Draws:2,Sum:-5 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:3,Sum:-2 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:9,Sum:13 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:1,Player Draws:2,Sum:20 ## Dealer Draws:1,Sum:-3,First Card:1
# Reward:-1,Player Draws:2,Sum:0 ## Dealer Draws:0,Sum:9,First Card:9
# ...
# Reward:0,Player Draws:5,Sum:21 ## Dealer Draws:2,Sum:21,First Card:7
# Reward:-1,Player Draws:1,Sum:-7 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:2,Sum:13 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:1,Sum:-8 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:1,Player Draws:3,Sum:19 ## Dealer Draws:6,Sum:17,First Card:4
# Reward:1,Player Draws:3,Sum:21 ## Dealer Draws:2,Sum:19,First Card:8
# Reward:1,Player Draws:3,Sum:19 ## Dealer Draws:5,Sum:-4,First Card:8
# Reward:-1,Player Draws:1,Sum:-8 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:1,Player Draws:4,Sum:18 ## Dealer Draws:2,Sum:-1,First Card:6
# Reward:1,Player Draws:3,Sum:18 ## Dealer Draws:3,Sum:-4,First Card:4
# Reward:1,Player Draws:9,Sum:20 ## Dealer Draws:2,Sum:0,First Card:6
# Reward:-1,Player Draws:2,Sum:14 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:1,Player Draws:4,Sum:20 ## Dealer Draws:2,Sum:18,First Card:6
# Reward:1,Player Draws:6,Sum:18 ## Dealer Draws:2,Sum:-2,First Card:9
# Reward:-1,Player Draws:3,Sum:0 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:1,Player Draws:5,Sum:21 ## Dealer Draws:5,Sum:23,First Card:1
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:1,Player Draws:5,Sum:18 ## Dealer Draws:10,Sum:0,First Card:8
# Reward:-1,Player Draws:1,Sum:-8 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:3,Sum:20 ## Dealer Draws:2,Sum:24,First Card:9
# Reward:-1,Player Draws:5,Sum:15 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:0,Player Draws:5,Sum:18 ## Dealer Draws:2,Sum:18,First Card:3
# Reward:-1,Player Draws:5,Sum:13 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:4,Sum:20 ## Dealer Draws:2,Sum:21,First Card:4
# Reward:1,Player Draws:3,Sum:20 ## Dealer Draws:2,Sum:0,First Card:4
# Reward:1,Player Draws:13,Sum:20 ## Dealer Draws:2,Sum:24,First Card:7
# Reward:1,Player Draws:3,Sum:19 ## Dealer Draws:1,Sum:0,First Card:3
# Reward:-1,Player Draws:2,Sum:17 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:1,Player Draws:6,Sum:19 ## Dealer Draws:7,Sum:25,First Card:5
# Reward:-1,Player Draws:3,Sum:-2 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:3,Sum:19 ## Dealer Draws:4,Sum:21,First Card:2
# Reward:1,Player Draws:6,Sum:20 ## Dealer Draws:1,Sum:-3,First Card:5
# Reward:1,Player Draws:1,Sum:18 ## Dealer Draws:2,Sum:-2,First Card:4
# Reward:-1,Player Draws:6,Sum:-2 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:3,Sum:-5 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:2,Sum:-1 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:1,Player Draws:4,Sum:18 ## Dealer Draws:7,Sum:17,First Card:6
# Reward:0,Player Draws:2,Sum:21 ## Dealer Draws:12,Sum:21,First Card:3
# Reward:1,Player Draws:2,Sum:19 ## Dealer Draws:4,Sum:25,First Card:2
# Reward:-1,Player Draws:5,Sum:-4 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:7,Sum:0 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:3,Sum:21 ## Dealer Draws:2,Sum:19,First Card:6
# Reward:-1,Player Draws:4,Sum:14 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:5,Sum:-1 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:3,Sum:-2 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:2,Sum:13 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:1,Player Draws:6,Sum:18 ## Dealer Draws:3,Sum:-6,First Card:1
# Reward:-1,Player Draws:7,Sum:-4 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:3,Sum:20 ## Dealer Draws:2,Sum:24,First Card:4
# Reward:0,Player Draws:3,Sum:18 ## Dealer Draws:4,Sum:18,First Card:2
# Reward:1,Player Draws:7,Sum:20 ## Dealer Draws:1,Sum:-3,First Card:3
# Reward:-1,Player Draws:6,Sum:17 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:1,Sum:-2 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:0,Player Draws:3,Sum:18 ## Dealer Draws:1,Sum:18,First Card:9
# Reward:1,Player Draws:1,Sum:19 ## Dealer Draws:1,Sum:-6,First Card:3
# Reward:-1,Player Draws:4,Sum:-1 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:5,Sum:17 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:2,Sum:17 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:4,Sum:-2 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:1,Player Draws:2,Sum:18 ## Dealer Draws:4,Sum:-4,First Card:8
# Reward:1,Player Draws:4,Sum:18 ## Dealer Draws:1,Sum:-3,First Card:3
# Reward:0,Player Draws:3,Sum:20 ## Dealer Draws:3,Sum:20,First Card:10
# Reward:-1,Player Draws:8,Sum:15 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:0,Player Draws:3,Sum:19 ## Dealer Draws:2,Sum:19,First Card:1
# Reward:-1,Player Draws:2,Sum:-4 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:1,Player Draws:4,Sum:21 ## Dealer Draws:7,Sum:22,First Card:7
# Reward:1,Player Draws:3,Sum:20 ## Dealer Draws:5,Sum:0,First Card:4
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:1,Player Draws:7,Sum:19 ## Dealer Draws:7,Sum:17,First Card:4
# Reward:0,Player Draws:4,Sum:21 ## Dealer Draws:2,Sum:21,First Card:1
# Reward:1,Player Draws:8,Sum:21 ## Dealer Draws:11,Sum:24,First Card:6
# Reward:1,Player Draws:3,Sum:19 ## Dealer Draws:2,Sum:23,First Card:9
# Reward:1,Player Draws:5,Sum:18 ## Dealer Draws:1,Sum:-5,First Card:3
# Reward:-1,Player Draws:2,Sum:0 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:1,Player Draws:5,Sum:19 ## Dealer Draws:5,Sum:23,First Card:1
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:2,Sum:-1 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:2,Sum:-4 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:1,Player Draws:2,Sum:20 ## Dealer Draws:3,Sum:19,First Card:6
# Reward:1,Player Draws:3,Sum:21 ## Dealer Draws:6,Sum:18,First Card:4
# Reward:-1,Player Draws:3,Sum:-1 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:3,Sum:-1 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:8,Sum:15 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:1,Sum:-3 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:4,Sum:18 ## Dealer Draws:4,Sum:20,First Card:9
# Reward:1,Player Draws:2,Sum:20 ## Dealer Draws:1,Sum:-3,First Card:1
# Reward:1,Player Draws:3,Sum:19 ## Dealer Draws:2,Sum:0,First Card:4
# Reward:-1,Player Draws:3,Sum:18 ## Dealer Draws:2,Sum:21,First Card:6
# Reward:-1,Player Draws:3,Sum:15 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:1,Player Draws:2,Sum:18 ## Dealer Draws:1,Sum:17,First Card:8
# Reward:1,Player Draws:2,Sum:19 ## Dealer Draws:1,Sum:17,First Card:7
# Reward:1,Player Draws:5,Sum:21 ## Dealer Draws:2,Sum:-2,First Card:1
# Reward:1,Player Draws:2,Sum:21 ## Dealer Draws:2,Sum:22,First Card:9
# Reward:1,Player Draws:2,Sum:19 ## Dealer Draws:2,Sum:17,First Card:7
# Reward:1,Player Draws:2,Sum:18 ## Dealer Draws:1,Sum:-2,First Card:3
# Reward:-1,Player Draws:3,Sum:0 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:1,Player Draws:3,Sum:18 ## Dealer Draws:3,Sum:-3,First Card:7
# Reward:-1,Player Draws:2,Sum:-2 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:5,Sum:16 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:1,Player Draws:4,Sum:21 ## Dealer Draws:3,Sum:25,First Card:6
# Reward:-1,Player Draws:2,Sum:17 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:1,Player Draws:3,Sum:19 ## Dealer Draws:2,Sum:17,First Card:5
# Reward:1,Player Draws:2,Sum:19 ## Dealer Draws:2,Sum:25,First Card:9
# Reward:0,Player Draws:5,Sum:20 ## Dealer Draws:5,Sum:20,First Card:2
# Reward:-1,Player Draws:2,Sum:17 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:2,Sum:15 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:4,Sum:21 ## Dealer Draws:4,Sum:23,First Card:9
# Reward:-1,Player Draws:1,Sum:-6 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:1,Sum:-5 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:1,Player Draws:5,Sum:20 ## Dealer Draws:2,Sum:26,First Card:6
# Reward:-1,Player Draws:10,Sum:12 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:2,Sum:-2 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:0,Player Draws:3,Sum:19 ## Dealer Draws:5,Sum:19,First Card:7
# Reward:-1,Player Draws:2,Sum:-1 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:7,Sum:17 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:1,Sum:-5 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:3,Sum:18 ## Dealer Draws:1,Sum:-2,First Card:2
# Reward:-1,Player Draws:2,Sum:12 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:2,Sum:12 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:3,Sum:-6 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:4,Sum:-7 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:3,Sum:19 ## Dealer Draws:3,Sum:17,First Card:1
# Reward:1,Player Draws:1,Sum:18 ## Dealer Draws:3,Sum:17,First Card:7
# Reward:1,Player Draws:4,Sum:21 ## Dealer Draws:6,Sum:20,First Card:5
# Reward:1,Player Draws:2,Sum:20 ## Dealer Draws:1,Sum:-1,First Card:8
# Reward:1,Player Draws:2,Sum:18 ## Dealer Draws:1,Sum:-2,First Card:7
# Reward:-1,Player Draws:2,Sum:18 ## Dealer Draws:4,Sum:19,First Card:8
# Reward:-1,Player Draws:2,Sum:13 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:1,Player Draws:3,Sum:18 ## Dealer Draws:4,Sum:25,First Card:8
# Reward:1,Player Draws:2,Sum:21 ## Dealer Draws:2,Sum:-4,First Card:4
# Reward:-1,Player Draws:11,Sum:17 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:6,Sum:18 ## Dealer Draws:3,Sum:-8,First Card:5
# Reward:1,Player Draws:3,Sum:20 ## Dealer Draws:5,Sum:18,First Card:9
# Reward:-1,Player Draws:5,Sum:18 ## Dealer Draws:2,Sum:21,First Card:7
# Reward:-1,Player Draws:10,Sum:-3 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:1,Sum:-2 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:1,Sum:-4 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:4,Sum:-2 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:1,Player Draws:4,Sum:19 ## Dealer Draws:1,Sum:17,First Card:10
# Reward:-1,Player Draws:4,Sum:-1 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:4,Sum:17 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:9,Sum:16 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:3,Sum:-4 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:6,Sum:17 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:5,Sum:-3 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:1,Sum:19 ## Dealer Draws:2,Sum:22,First Card:5
# Reward:-1,Player Draws:9,Sum:15 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:1,Sum:-2 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:11,Sum:-2 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:7,Sum:18 ## Dealer Draws:3,Sum:19,First Card:6
# Reward:-1,Player Draws:1,Sum:-6 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:5,Sum:18 ## Dealer Draws:1,Sum:-7,First Card:1
# Reward:-1,Player Draws:3,Sum:19 ## Dealer Draws:4,Sum:20,First Card:4
# Reward:-1,Player Draws:3,Sum:-5 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:-1,Player Draws:7,Sum:12 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:1,Sum:-1 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:2,Sum:21 ## Dealer Draws:3,Sum:-2,First Card:7
# Reward:-1,Player Draws:4,Sum:19 ## Dealer Draws:1,Sum:20,First Card:10
# Reward:1,Player Draws:1,Sum:19 ## Dealer Draws:1,Sum:0,First Card:2
# Reward:-1,Player Draws:2,Sum:17 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:2,Sum:-5 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:1,Player Draws:2,Sum:21 ## Dealer Draws:1,Sum:-3,First Card:4
# Reward:-1,Player Draws:7,Sum:15 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:2,Sum:-3 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:2,Sum:17 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:2,Sum:17 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:6,Sum:12 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:1,Player Draws:4,Sum:21 ## Dealer Draws:1,Sum:0,First Card:3
# Reward:1,Player Draws:1,Sum:19 ## Dealer Draws:1,Sum:-2,First Card:8
# Reward:-1,Player Draws:4,Sum:16 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:7,Sum:20 ## Dealer Draws:2,Sum:21,First Card:9
# Reward:1,Player Draws:3,Sum:18 ## Dealer Draws:4,Sum:-2,First Card:8
# Reward:1,Player Draws:4,Sum:19 ## Dealer Draws:1,Sum:0,First Card:1
# Reward:1,Player Draws:5,Sum:21 ## Dealer Draws:1,Sum:-3,First Card:5
# Reward:1,Player Draws:2,Sum:20 ## Dealer Draws:2,Sum:18,First Card:6
# Reward:-1,Player Draws:2,Sum:18 ## Dealer Draws:3,Sum:20,First Card:5
# Reward:1,Player Draws:4,Sum:21 ## Dealer Draws:2,Sum:-8,First Card:8
# Reward:-1,Player Draws:2,Sum:0 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:3,Sum:-4 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:11,Sum:-2 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:1,Sum:-5 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:1,Player Draws:3,Sum:21 ## Dealer Draws:3,Sum:19,First Card:7
# Reward:-1,Player Draws:5,Sum:-1 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:0,Player Draws:2,Sum:20 ## Dealer Draws:6,Sum:20,First Card:1
# Reward:1,Player Draws:7,Sum:18 ## Dealer Draws:5,Sum:-2,First Card:9
# Reward:1,Player Draws:4,Sum:19 ## Dealer Draws:1,Sum:-2,First Card:3
# Reward:-1,Player Draws:1,Sum:-7 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:-1,Player Draws:3,Sum:17 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:1,Player Draws:6,Sum:19 ## Dealer Draws:4,Sum:17,First Card:9
# Reward:1,Player Draws:7,Sum:21 ## Dealer Draws:2,Sum:19,First Card:10
# Reward:1,Player Draws:7,Sum:19 ## Dealer Draws:4,Sum:18,First Card:6
# Reward:-1,Player Draws:6,Sum:17 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:8,Sum:15 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:1,Player Draws:2,Sum:18 ## Dealer Draws:1,Sum:-1,First Card:9
# Reward:1,Player Draws:5,Sum:20 ## Dealer Draws:1,Sum:-5,First Card:2
# Reward:1,Player Draws:4,Sum:19 ## Dealer Draws:2,Sum:0,First Card:3
# Reward:-1,Player Draws:9,Sum:-1 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:1,Player Draws:1,Sum:19 ## Dealer Draws:5,Sum:17,First Card:4
# Reward:-1,Player Draws:2,Sum:-1 ## Dealer Draws:0,Sum:3,First Card:3
# Reward:0,Player Draws:2,Sum:18 ## Dealer Draws:2,Sum:18,First Card:2
# Reward:1,Player Draws:4,Sum:20 ## Dealer Draws:2,Sum:17,First Card:9
# Reward:1,Player Draws:3,Sum:18 ## Dealer Draws:5,Sum:0,First Card:7
# Reward:1,Player Draws:3,Sum:18 ## Dealer Draws:4,Sum:25,First Card:9
# Reward:-1,Player Draws:2,Sum:18 ## Dealer Draws:2,Sum:21,First Card:5
# Reward:-1,Player Draws:2,Sum:-1 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:5,Sum:13 ## Dealer Draws:0,Sum:1,First Card:1
# Reward:1,Player Draws:2,Sum:20 ## Dealer Draws:1,Sum:-6,First Card:3
# Reward:-1,Player Draws:5,Sum:14 ## Dealer Draws:0,Sum:8,First Card:8
# Reward:-1,Player Draws:1,Sum:-2 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:4,Sum:16 ## Dealer Draws:0,Sum:6,First Card:6
# Reward:-1,Player Draws:1,Sum:-5 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:6,Sum:-6 ## Dealer Draws:0,Sum:9,First Card:9
# Reward:-1,Player Draws:2,Sum:16 ## Dealer Draws:0,Sum:2,First Card:2
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:7,First Card:7
# Reward:-1,Player Draws:2,Sum:-2 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:1,Player Draws:7,Sum:19 ## Dealer Draws:1,Sum:-3,First Card:1
# Reward:1,Player Draws:4,Sum:21 ## Dealer Draws:1,Sum:-5,First Card:2
# Reward:-1,Player Draws:1,Sum:0 ## Dealer Draws:0,Sum:10,First Card:10
# Reward:-1,Player Draws:5,Sum:-4 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:1,Player Draws:1,Sum:18 ## Dealer Draws:1,Sum:17,First Card:10
# Reward:-1,Player Draws:4,Sum:-8 ## Dealer Draws:0,Sum:4,First Card:4
# Reward:-1,Player Draws:3,Sum:14 ## Dealer Draws:0,Sum:5,First Card:5
# Reward:-1,Player Draws:1,Sum:-4 ## Dealer Draws:0,Sum:7,First Card:7
